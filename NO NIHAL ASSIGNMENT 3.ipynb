# %% [markdown]
# ITERATOR

# %% [markdown]
# Q1 Convert a string into an iterator and print each charcater using next().

# %%
text = "harshita"
text_iter = iter(text)

print(next(text_iter))
print(next(text_iter))
print(next(text_iter))
print(next(text_iter))
# Out:
# h
# a
# r
# s

# %% [markdown]
# Q2 By using for loop

# %%
data = [2,4,6,8,10]
iterator = iter(data)

for num in iterator:
 print(num)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# Q3 Use "for" loop to iterate over an iterator

# %%
list = iter(["h","b","c","t"])
for i in list:
    print(i)
# Out:
# h
# b
# c
# t

# %% [markdown]
# Q4 Manually iterate through a tuple using an iterator and a while loop.

# %%
sports = ("football", "cricket", "baseball")
sports_iter = iter(sports)

while True:
    try:
        print(next(sports_iter))
    except StopIteration:
        break
# Out:
# football
# cricket
# baseball

# %% [markdown]
# Q5 Use next to iterate numbers

# %%
range_iter = iter(range(10))

print(next(range_iter))
print(next(range_iter))
print(next(range_iter))
print(next(range_iter))

# %% [markdown]
# Decorator

# %% [markdown]
# Q1: Create a decorator that logs function name and parameters. The function should take exactly 2 arguments.

# %%
def log_decorator(func):
    def wrapper(a, b):
        print(f"Calling {func.__name__} with arguments: {a}, {b}")
        return func(a, b)
    return wrapper

@log_decorator
def multiply(x, y):
    return x * y

print(multiply(4, 9))
# Out:
# Calling multiply with arguments: 4, 9
# 36

# %% [markdown]
# Q2: Create a decorator that measures execution time of a function with no parameters.

# %%
import time

def timer_decorator(func):
    def wrapper():
        start = time.time()
        result = func()
        end = time.time()
        print(f"Time taken: {end - start:.4f} seconds")
        return result
    return wrapper

@timer_decorator
def do_work():
    time.sleep(1)
    print("Work done.")

do_work()
# Out:
# Work done.
# Time taken: 1.0015 seconds

# %% [markdown]
# Q3: Create a decorator that checks if a user is "admin".

# %%
def requires_admin(func):
    def wrapper(user):
        if user != "admin":
            print("Access denied")
            return
        return func(user)
    return wrapper

@requires_admin
def access_dashboard(user):
    print(f"{user} accessed the dashboard.")

access_dashboard("guest")
access_dashboard("admin")
# Out:
# Access denied
# admin accessed the dashboard.

# %% [markdown]
# Q4: Create a memoization decorator for a function that takes one integer parameter.

# %%
def memoize(func):
    cache = {}  
    def wrapper(n):
        if n in cache:
            print("Fetching from cache")
            return cache[n]
        else:
            print("Computing result")
            result = func(n)
            cache[n] = result
            return result

    return wrapper


@memoize
def square(n):
    return n * n



print(square(4))  
print(square(4)) 
print(square(5))
# Out:
# Computing result
# 16
# Fetching from cache
# 16
# Computing result
# 25

# %% [markdown]
# Q5: Create a decorator that prints how long a function takes to run.

# %%
import time

def timer(func):
    def wrapper():
        start = time.time()
        func()
        end = time.time()
        print("Time taken:", end - start)
    return wrapper

@timer
def slow_function():
    time.sleep(2)
    print("Done")

slow_function()
# Out:
# Done
# Time taken: 2.000722885131836

# %% [markdown]
# Generator

# %% [markdown]
# Q1 create a generator for fibonacci series of a number

# %%
def fibonacci(n):
    a, b = 0, 1
    for n in range(n):
        yield a
        a, b = b, a + b

fib = fibonacci(7)
print(list(fib))
# Out:
# [0, 1, 1, 2, 3, 5, 8]

# %% [markdown]
#  Q2 Write a generator function that takes a number n .Yields all even numbers from 1 to n

# %%
def even_numbers(n):
    for i in range(1, n + 1):
        if i % 2 == 0:
            yield i

gen = even_numbers(10)
print(list(gen))
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# Q3 Write a generator that  takes a number n .Yields square of numbers from 1 to n.

# %%
def squares(n):
    for i in range(1, n + 1):
        yield i * i

gen = squares(5)
print(list(gen))
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# Q4 Write a generator that takes two inputs: n and x .Yields first n multiples of x

# %%
def multiples(n, x):
    for i in range(1, n + 1):
        yield i * x

gen = multiples(5, 3)
print(list(gen))
# Out:
# [3, 6, 9, 12, 15]

# %% [markdown]
# Q5 Write a generator that takes a number n and does countdown from it

# %%
def countdown(n):
    while n > 0:
        yield n
        n -= 1

gen = countdown(5)
print(list(gen))
# Out:
# [5, 4, 3, 2, 1]
