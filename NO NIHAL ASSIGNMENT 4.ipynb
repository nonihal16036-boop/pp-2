# %% [markdown]
#  Simple Webscraping

# %%
import requests
from bs4 import BeautifulSoup

# %%
url= "https://www.scrapethissite.com/pages/forms/"
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text,"html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping</title>
# <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# <link href="/static/css/styles.css" rel="stylesheet" type="text/css"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping
#   </title>
#   <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# ...

# %%
title = soup.title
print(title.text)
# Out:
# Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping

# %%
first_paragraph = soup.find("a")
print(first_paragraph.text)
# Out:
#                                 Scrape This Site

# %%
teams = soup.find_all("tr", class_="team")

for team in teams:
    cols = team.find_all("td")
    
    name = cols[0].text.strip()   # Team name
    wins = cols[2].text.strip()   # Wins column
    
    print(f"{name} - {wins}")
# Out:
# Boston Bruins - 44
# Buffalo Sabres - 31
# Calgary Flames - 46
# Chicago Blackhawks - 49
# Detroit Red Wings - 34
# Edmonton Oilers - 37
# Hartford Whalers - 31
# Los Angeles Kings - 46
# Minnesota North Stars - 27
# Montreal Canadiens - 39
# New Jersey Devils - 32
# New York Islanders - 25
# New York Rangers - 36
# Philadelphia Flyers - 33
# Pittsburgh Penguins - 41
# Quebec Nordiques - 16
# St. Louis Blues - 47
# Toronto Maple Leafs - 23
# Vancouver Canucks - 28
# Washington Capitals - 37
# Winnipeg Jets - 26
# Boston Bruins - 36
# Buffalo Sabres - 31
# Calgary Flames - 31
# Chicago Blackhawks - 36

# %%
Webscraping using def

# %%
def scrape_quotes():
    import requests
    from bs4 import BeautifulSoup

    url = "http://quotes.toscrape.com"
    response = requests.get(url)

    soup = BeautifulSoup(response.text, "html.parser")

    quotes = soup.find_all("span", class_="text")
    authors = soup.find_all("small", class_="author")

    for quote, author in zip(quotes, authors):
        print(f"{quote.text.strip()} - {author.text.strip()}")


# calling the function
scrape_quotes()
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.” - Albert Einstein
# “It is our choices, Harry, that show what we truly are, far more than our abilities.” - J.K. Rowling
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.” - Albert Einstein
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.” - Jane Austen
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.” - Marilyn Monroe
# “Try not to become a man of success. Rather become a man of value.” - Albert Einstein
# “It is better to be hated for what you are than to be loved for what you are not.” - André Gide
# “I have not failed. I've just found 10,000 ways that won't work.” - Thomas A. Edison
# ...

# %% [markdown]
# Webscraping using headers

# %%
import requests
from bs4 import BeautifulSoup

url = "http://books.toscrape.com/"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, "html.parser")

book_names = soup.find_all("h3")
prices = soup.find_all("p", class_="price_color")

for name, price in zip(book_names, prices):
    book_title = name.find("a").get("title")
    print(f"{book_title} - {price.text.strip()}")
# Out:
# A Light in the Attic - Â£51.77
# Tipping the Velvet - Â£53.74
# Soumission - Â£50.10
# Sharp Objects - Â£47.82
# Sapiens: A Brief History of Humankind - Â£54.23
# The Requiem Red - Â£22.65
# The Dirty Little Secrets of Getting Your Dream Job - Â£33.34
# The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull - Â£17.93
# The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics - Â£22.60
# The Black Maria - Â£52.15
# Starving Hearts (Triangular Trade Trilogy, #1) - Â£13.99
# Shakespeare's Sonnets - Â£20.66
# Set Me Free - Â£17.46
# Scott Pilgrim's Precious Little Life (Scott Pilgrim #1) - Â£52.29
# Rip it Up and Start Again - Â£35.02
# Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991 - Â£57.25
# Olio - Â£23.88
# Mesaerion: The Best Science Fiction Stories 1800-1849 - Â£37.59
# Libertarianism for Beginners - Â£51.33
# It's Only the Himalayas - Â£45.17

# %% [markdown]
# Web Scraping Using Enumerate

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.scrapethissite.com/pages/simple/"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

countries = soup.find_all("h3", class_="country-name")
capitals = soup.find_all("span", class_="country-capital")

for i, (country, capital) in enumerate(zip(countries, capitals), start=1):
    country_name = country.text.strip()
    capital_name = capital.text.strip()
    
    print(f"{i}. {country_name} - {capital_name}")
# Out:
# 1. Andorra - Andorra la Vella
# 2. United Arab Emirates - Abu Dhabi
# 3. Afghanistan - Kabul
# 4. Antigua and Barbuda - St. John's
# 5. Anguilla - The Valley
# 6. Albania - Tirana
# 7. Armenia - Yerevan
# 8. Angola - Luanda
# 9. Antarctica - None
# 10. Argentina - Buenos Aires
# 11. American Samoa - Pago Pago
# 12. Austria - Vienna
# 13. Australia - Canberra
# 14. Aruba - Oranjestad
# 15. Åland - Mariehamn
# 16. Azerbaijan - Baku
# 17. Bosnia and Herzegovina - Sarajevo
# 18. Barbados - Bridgetown
# 19. Bangladesh - Dhaka
# 20. Belgium - Brussels
# 21. Burkina Faso - Ouagadougou
# 22. Bulgaria - Sofia
# 23. Bahrain - Manama
# 24. Burundi - Bujumbura
# 25. Benin - Porto-Novo
# 26. Saint Barthélemy - Gustavia
# 27. Bermuda - Hamilton
# 28. Brunei - Bandar Seri Begawan
# 29. Bolivia - Sucre
# 30. Bonaire - Kralendijk
# 31. Brazil - Brasília
# 32. Bahamas - Nassau
# 33. Bhutan - Thimphu
# 34. Bouvet Island - None
# 35. Botswana - Gaborone
# 36. Belarus - Minsk
# 37. Belize - Belmopan
# ...

# %% [markdown]
# Webscraping with Table Operactions

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population"
headers = {"User-Agent":"Mozilla/5.0"} #avoid blocking
response=requests.get(url,headers=headers)
soup = BeautifulSoup(response.text,"html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-menu-disabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 skin-theme-clientpref-day vector-sticky-header-enabled wp25eastereggs-enable-clientpref-1 vector-toc-available skin-theme-clientpref-thumb-standard" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of countries and dependencies by population - Wikipedia</title>
# ...

# %%
tables = soup.find_all("table",class_="wikitable")

# %%
if not tables:
    raise ValueError("No tables with class 'wikitable' found on the page")
table =tables[0]

# %%
rows=table.find_all("tr")

# %%
data =[]
for row in rows:
    cols=row.find_all(["td","th"])
    cols=[col.get_text(strip=True)for col in cols]
    data.append(cols)

df=pd.DataFrame(data)

print(df.head())
# Out:
#                0              1          2            3  \
# 0       Location     Population  % ofworld         Date
# 1          World  8,232,000,000       100%  13 Jun 2025
# 2          India  1,417,492,000      17.2%   1 Jul 2025
# 3          China  1,404,890,000      17.1%  31 Dec 2025
# 4  United States    341,784,857       4.1%   1 Jul 2025
#
#                                             4      5
# 0  Source (official or fromtheUnited Nations)  Notes
# 1                         UN projection[1][3]
# 2                      Official projection[4]    [b]
# 3                        Official estimate[5]    [c]
# 4                        Official estimate[6]    [d]

# %%
df.columns = df.iloc[0]
df = df[1:]
df.columns = df.columns.str.strip()
df.head()
# Out:
# 0       Location     Population % ofworld         Date  \
# 1          World  8,232,000,000      100%  13 Jun 2025
# 2          India  1,417,492,000     17.2%   1 Jul 2025
# 3          China  1,404,890,000     17.1%  31 Dec 2025
# 4  United States    341,784,857      4.1%   1 Jul 2025
# 5      Indonesia    288,315,089      3.5%  31 Dec 2025
#
# 0 Source (official or fromtheUnited Nations) Notes
# 1                        UN projection[1][3]
# 2                     Official projection[4]   [b]
# 3                       Official estimate[5]   [c]
# 4                       Official estimate[6]   [d]
# 5              National annual projection[7]

# %%
#selecting specific columns
df[["Location","% ofworld"]]
# Out:
# 0                              Location % ofworld
# 1                                 World      100%
# 2                                 India     17.2%
# 3                                 China     17.1%
# 4                         United States      4.1%
# 5                             Indonesia      3.5%
# ..                                  ...       ...
# 236         Christmas Island(Australia)        0%
# 237                   Niue(New Zealand)        0%
# 238                        Vatican City        0%
# 239  Cocos (Keeling) Islands(Australia)        0%
# 240                Pitcairn Islands(UK)        0%
#
# [240 rows x 2 columns]

# %%
#filtering rows
df[df["Location"]=="India"]
# Out:
# 0 Location     Population % ofworld        Date  \
# 2    India  1,417,492,000     17.2%  1 Jul 2025
#
# 0 Source (official or fromtheUnited Nations) Notes
# 2                     Official projection[4]   [b]

# %%
#sorting data
df.sort_values(by='Population', ascending=True)
# Out:
# 0               Location Population % ofworld         Date  \
# 161             Djibouti  1,066,809     0.01%  20 May 2024
# 160             Eswatini  1,235,549     0.01%   1 Jul 2024
# 159            Mauritius  1,241,856     0.02%  31 Dec 2025
# 158              Estonia  1,362,954     0.02%   1 Jan 2026
# 157  Trinidad and Tobago  1,367,764     0.02%  30 Jun 2025
# ..                   ...        ...       ...          ...
# 96              Honduras  9,892,632      0.1%   1 Jul 2024
# 165                 Fiji    902,623     0.01%   1 Jan 2026
# 164              Comoros    944,388     0.01%         2026
# 163               Guyana    956,044     0.01%  31 Dec 2024
# 162               Cyprus    983,000     0.01%  31 Dec 2024
#
# 0   Source (official or fromtheUnited Nations) Notes
# 161                    2024 census result[176]
# 160                   Official projection[175]
# 159                     National estimate[174]
# 158                     Official estimate[173]
# ...

# %%
# handle missing data
df.isnull()
# Out:
# 0    Location  Population  % ofworld   Date  \
# 1       False       False      False  False
# 2       False       False      False  False
# 3       False       False      False  False
# 4       False       False      False  False
# 5       False       False      False  False
# ..        ...         ...        ...    ...
# 236     False       False      False  False
# 237     False       False      False  False
# 238     False       False      False  False
# 239     False       False      False  False
# 240     False       False      False  False
#
# 0    Source (official or fromtheUnited Nations)  Notes
# 1                                         False  False
# 2                                         False  False
# 3                                         False  False
# 4                                         False  False
# 5                                         False  False
# ..                                          ...    ...
# ...

# %%
df = df.dropna()

# %%
df['Population'] = pd.to_numeric(df['Population'].astype(str).str.replace(',', ''), errors='coerce')
df['% ofworld'] = pd.to_numeric(df['% ofworld'].astype(str).str.replace(',', ''), errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 1 to 240
# Data columns (total 6 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Location                                    240 non-null    object
#  1   Population                                  240 non-null    int64
#  2   % ofworld                                   0 non-null      float64
#  3   Date                                        240 non-null    object
#  4   Source (official or fromtheUnited Nations)  240 non-null    object
#  5   Notes                                       240 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 11.4+ KB

# %%
df['Population_in_millions'] = df['Population'] / 1_000_000
df.head()
# Out:
# 0       Location  Population  % ofworld         Date  \
# 1          World  8232000000        NaN  13 Jun 2025
# 2          India  1417492000        NaN   1 Jul 2025
# 3          China  1404890000        NaN  31 Dec 2025
# 4  United States   341784857        NaN   1 Jul 2025
# 5      Indonesia   288315089        NaN  31 Dec 2025
#
# 0 Source (official or fromtheUnited Nations) Notes  Population_in_millions
# 1                        UN projection[1][3]                   8232.000000
# 2                     Official projection[4]   [b]             1417.492000
# 3                       Official estimate[5]   [c]             1404.890000
# 4                       Official estimate[6]   [d]              341.784857
# 5              National annual projection[7]                    288.315089

# %%
df.to_csv("data.csv",index=False)

# %%
for index, row in df.iterrows():
   print(row['Location'],"-", row['Population_in_millions'])
# Out:
# World - 8232.0
# India - 1417.492
# China - 1404.89
# United States - 341.784857
# Indonesia - 288.315089
# Pakistan - 241.499431
# Nigeria - 223.8
# Brazil - 213.421037
# Bangladesh - 169.828911
# Russia - 146.028325
# Mexico - 131.001723
# Japan - 122.85
# Philippines - 114.1236
# Democratic Republic of the Congo - 112.832
# Ethiopia - 111.652998
# Egypt - 107.868296
# Vietnam - 102.3
# Iran - 86.563
# Turkey - 86.092168
# Germany - 83.497147
# United Kingdom - 69.487
# France - 69.081996
# Tanzania - 68.153004
# Thailand - 65.826149
# South Africa - 63.100945
# Italy - 58.942828
# Kenya - 53.330978
# Colombia - 53.057212
# Sudan - 51.662
# Myanmar - 51.375327
# South Korea - 51.111158
# Spain - 49.570725
# Algeria - 47.4
# Argentina - 46.387098
# Iraq - 46.118793
# Uganda - 45.905417
# Afghanistan - 43.844
# Canada - 41.472081
# Uzbekistan - 38.236704
# Poland - 37.314
# Morocco - 36.82833
# Angola - 36.604681
# Saudi Arabia - 35.30028
# Peru - 34.350244
# Malaysia - 34.3344
# ...
